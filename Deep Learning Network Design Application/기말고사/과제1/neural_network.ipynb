# %%
# 리스트 7-1-(1)
import numpy as np

# 데이터 생성
np.random.seed(seed = 1) # 난수를 고정
N = 200 # 데이터의 수
K = 3 #  분포의 수, 클래스의 수
T = np.zeros((N, 3), dtype = np.uint8)
X = np.zeros((N, 2))
X_range0 = [-3, 3]
X_range1 = [-3, 3]
Mu = np.array([[-.5, -.5], [.5, 1.0], [1, -.5]]) # 분포의 중심
Sig = np.array([[.7, .7], [.8, .3], [.3, .8]]) # 분포의 분산
Pi = np.array([0.4, 0.8, 1]) # 각 분포에 대한 비율

for n in range(N):
    wk = np.random.rand()
    
    for k in range(K):
        if wk < Pi[k]:
            T[n, k] = 1
            break
    
    for k in range(2):
        X[n, k] = np.random.randn() * Sig[T[n, :] == 1, k] + Mu[T[n, :] == 1, k]

# %%
# 리스트 7-1-(2)
# 2분류 데이터를 테스트 훈련 데이터로 분할
TestRatio = 0.5
X_n_training = int(N * TestRatio)
X_train = X[:X_n_training, :]
X_test = X[X_n_training:,:]
T_train = T[:X_n_training, :]
T_test = T[X_n_training:,:]

# 데이터를 'class_data.npz' 에 저장
np.savez('class_data.npz', X_train = X_train, T_train = T_train, X_test = X_test, T_test = T_test, X_range0 = X_range0, X_range1 = X_range1)

# %%
#리스트 7-1-(3)
import matplotlib.pyplot as plt
# %matplotlib inline

# 데이터를 그리기
def Show_data(x, t):
    wk, n = t.shape
    c = [[0, 0, 0], [0.5, 0.5, 0.5], [1, 1, 1]] # 컬러 값 설정
    #c = [[1, 0, 0], [0, 1, 0], [0, 0, 1]] # 컬러 값 설정 [r, g, b]
    
    for i in range(n):
         plt.plot(x[t[:, i] == 1, 0], x[t[:, i] == 1, 1], linestyle = 'none', markeredgecolor = 'black', marker = 'o', color = c[i], alpha = 0.8)
        # K 값을 0, 1, 2로 바꾸어 주면서 부류벡터 t 에 접근 부류번호가 일치하는 인덱스드을 모두 찾아준다
        # 따라서, 부류가 0번인 샘플들의 (x1, x2) 위치에 포인트를 먼저 다 찍고, 그 다음 부류로 순차적으로 찍게 된다
    plt.grid(True)
    
        
# 메인
plt.figure(1, figsize = (8, 3.7))
plt.subplot(1, 2, 1)
Show_data(X_train, T_train)
plt.xlim(X_range0)
plt.ylim(X_range1)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.title('Training Data')

plt.subplot(1, 2, 2)
Show_data(X_test, T_test)
plt.xlim(X_range0)
plt.ylim(X_range1)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.title('Test Data')

plt.show()

# %%
# 리스트 7-1-(4)
# 시그모이드 함수

def Sigmoid(x):
    y = 1 / (1+ np.exp(-x))
    return y

# 네트워크
def FNN(wv, M, K, x): #Feed-forward Neural Network
    #wv : 전체 가중치를 1차원 행벡터로 모아 표현해둔 벡터
    #M : 은닉층 출력의 수
    #K : 출력층 출력의 수
    N, D = x.shape # 입력의 차원 N= 샘플 수, D=특징벡터의 길이(차원 수)
    w = wv[:M * (D+1)] #입력층과 은닉층 사이의 가중치를 가져온다
    w = w.reshape(M, (D+1)) # M * (D+1) 행렬로 변환
    v = wv[M * (D + 1): ] #은닉층과 출력층 사이의 가중치를 가져온다
    v = v.reshape((K, M + 1))
    b = np.zeros((N, M + 1)) # 은닉층 뉴런의 입력 총합
    z = np.zeros((N, M + 1)) # 은닉층 뉴런의 출력
    a = np.zeros((N, K)) #출력층 뉴런의 입력 총합
    y = np.zeros((N, K)) #출력층 뉴런의 출력

    for n in range(N):
        #은닉층의 계산
        for m in range(M):
            b[n, m] = np.dot(w[m, :], np.r_[x[n, :], 1])
            # (a) np.r_[x[n, :], 1]) 더미 입력(바이어스)를
            # 입력 벡터의 3번째 요소로 덧붙이는 부분
            z[n, m] = Sigmoid(b[n, m])

        #출력층의 계산
        z[n, M] = 1 #더미 뉴런(바이어스)
        wkz = 0

        for k in range(K):
            a[n, k] = np.dot(v[k, :], z[n, :])
            wkz = wkz + np.exp(a[n, k])

        for k in range(K):
            y[n, k] = np.exp(a[n, k]) / wkz #최종 출력 값 계산

    return y, a, z, b

WV = np.ones(15) #16개의 매개변수를 모두 1로 초기화
M = 2
K = 3
FNN(WV, M, K, X_train[:2, :])
# 현재 모델에 대한 입력데이터 2개에 대한 출력 y
# Out:
# (array([[0.33333333, 0.33333333, 0.33333333],
#         [0.33333333, 0.33333333, 0.33333333]]),
#  array([[2.6971835 , 2.6971835 , 2.6971835 ],
#         [1.49172649, 1.49172649, 1.49172649]]),
#  array([[0.84859175, 0.84859175, 1.        ],
#         [0.24586324, 0.24586324, 1.        ]]),
#  array([[ 1.72359839,  1.72359839,  0.        ],
#         [-1.12079826, -1.12079826,  0.        ]]))

# %%
# 리스트 7-1-(5)
# 평균 교차 엔트로피 오차
def CE_FNN(wv, M, K, x, t):
    N, D = x.shape
    y,a,z,b=FNN(wv,M,K,x)
    ce = -np.dot(np.log(y.reshape(-1)), t.reshape(-1)) / N
    # N * K 행렬인 y와 t 행렬을 reshape(-1) 을통하여
    # 1차원 행백터로 변환 시킨 후 내적을 구하면
    # 교차엔트로피오차를 쉽게 구할 수 있다.
    return ce

#test
WV = np.ones(15)
M = 2
K = 3
CE_FNN(WV, M, K, X_train[:2, :], T_train[:2, :])
# Out:
# 1.0986122886681098

# %%
# 리스트 7-1-(6)
# 수치 미분 (근사적인 기울기)

def dCE_FNN_num(wv, M, K, x, t):
    epsilon = 0.001
    dwv = np.zeros_like(wv)

    for iwv in range(len(wv)):
        wv_modified = wv.copy()
        wv_modified[iwv] = wv[iwv] - epsilon
        mse1 = CE_FNN(wv_modified, M, K, x, t)
        wv_modified[iwv] = wv[iwv] + epsilon
        mse2 = CE_FNN(wv_modified, M, K, x, t)
        dwv[iwv] = (mse2 - mse1) / (2 * epsilon)
    return dwv

# dVW 의 표시
def Show_WV(wv, M):
    N = wv.shape[0]
    plt.bar(range(1, M * 3 + 1), wv[ : M * 3], align = "center", color = 'black', label = '$dw_{i-1}$')
    plt.bar(range(M * 3 + 1, N + 1), wv[M * 3 : ], align = "center", color = 'cornflowerblue', label = '$dv_{i-1}$')
    plt.xticks(range(1, N + 1))
    plt.xlim(0, N +1)
    plt.legend(loc = "lower left", fontsize = 14)
    plt.xlabel('$i$', fontsize=14)
    
    
# 메인
K = 3
nWV = M * 3 + K * (M + 1)
np.random.seed(1)
WV = np.random.normal(0, 1, nWV)
dWV = dCE_FNN_num(WV, M, K, X_train[: 2, :], T_train[:2, :])
plt.figure(1, figsize = (8, 5))
Show_WV(dWV, M)
plt.show()

# %%
# 리스트 7-1-(7)
# 수치 미분법에 의한 경사 하강법
import time
def Fit_FNN_num(wv_init, M, K, x_train, t_train, x_test, t_test, n, alpha):
    wvt = wv_init
    err_train = np.zeros(n)
    err_test = np.zeros(n)
    wv_hist = np.zeros((n, len(wv_init)))
    epsilon = 0.001

    for i in range(n):
        # for 루프 내에서는 wvt 를 dCE_FNN_num으로 갱신하여,
        # 매번 훈련 데이터의 오차와 테스트 데이터의 오차를 계산
        wvt = wvt -alpha * dCE_FNN_num(wvt, M, K, x_train, t_train)
        err_train[i] = CE_FNN(wvt, M, K, x_train, t_train)
        err_test[i] = CE_FNN(wvt, M, K, x_test, t_test)
        wv_hist[i, :] = wvt

    return wvt, wv_hist, err_train, err_test

# 메인
startTime = time.time()
M = 2
K = 3
np.random.seed(1)
WV_init = np.random.normal(0, 0.01, M * 3 + K * ( M + 1 ))
N_step = 1000 # (B) 학습 단계
alpha = 0.5 # 학습률
WV, WV_hist, Err_train, Err_test = Fit_FNN_num(
    WV_init, M, K, X_train, T_train, X_test, T_test, N_step, alpha)
calculation_time = time.time()- startTime
print("Calculation time : {0: .3f} sec" .format(calculation_time))
# Out:
# Calculation time :  225.014 sec

# %%
# 리스트 7-1-(8)
# 학습 오차의 표시
plt.figure(1, figsize = (3, 3))
plt.plot(Err_train, 'black', label = 'training')
plt.plot(Err_test, 'cornflowerblue', label = 'test')
plt.xlabel('steps', fontsize = 11)
plt.ylabel('CE', fontsize = 11)
plt.ylim(0, )
plt.legend()
plt.show()

# %%
# 리스트 7-1-(9)
# 가중치의 시간 변화의 표시
plt.figure(1, figsize = (3, 3))
plt.plot(WV_hist[:, : M * 3], 'black')
plt.plot(WV_hist[:, M * 3 :], 'cornflowerblue')
plt.xlabel("steps")
plt.show()
print("Black: w, Cornflowerblue: v")
# Out:
# Black: w, Cornflowerblue: v

# %%
# 리스트 7-1-(10)
# 경계선 표시 함수
# 각각의 카테고리에서 0.5, 0.8, 0.9 이상의 출력을 얻을 수 있는 영역을 등고선으로 표시
def show_FNN(wv, M, K):
    xn = 60 # 등고선 표시 해상도
    x0 = np.linspace(X_range0[0], X_range0[1], xn)
    x1 = np.linspace(X_range1[0], X_range1[1], xn)
    xx0, xx1 = np.meshgrid(x0, x1)
    x = np.c_[np.reshape(xx1, (xn * xn, 1)), np.reshape(xx0, (xn * xn, 1))] # np.c_ column 추가
    y, a, z, b = FNN(wv, M, K, x)
    plt.figure(1, figsize = (5, 5))
    
    for ic in range(K):
        f = y[: , ic]
        f = f.reshape(xn, xn)
        f = f.T
        cont = plt.contour(xx0, xx1, f, levels = [0.5, 0.8, 0.9], colors = ['gray', 'cornflowerblue', 'black'])
        cont.clabel(fmt = '%1.1f', fontsize = 9)
        
    plt.xlim(X_range0)
    plt.ylim(X_range1)
    
    
# 경계선 표시
plt.figure(1, figsize = (4, 4))
Show_data(X_test,T_test)
show_FNN(WV, M, K)
plt.xlabel('$x_0$', fontsize = 14)
plt.ylabel('$x_1$', fontsize = 14)
plt.show()

# %%
# 리스트 7-1-(11)
# 해석적 미분
# 오차 역전파법의 구현
def dCE_FNN(wv, M, K, x, t):
    N, D = x.shape

    # wv를 w와 v로 되돌림
    w = wv[ : M * (D + 1)]
    w = w.reshape(M, (D + 1))
    v = wv[ M * (D + 1) :]
    v = v.reshape((K, M+1))

    # (1) x 를 입력하여 y 를 얻음(전방계산)
    y, a, z, b = FNN(wv, M, K, x)

    #출력변수의 준비
    dwv = np.zeros_like(wv)
    dw = np.zeros((M, D+1))
    dv = np.zeros((K, M+1))
    delta1 = np.zeros(M) # 1층 오차
    delta2 = np.zeros(K) # 2층 오차 (k=0 부분은 사용하지 않음)

    for n in range(N):
        # (2) 출력층의 오차 구하기
        for k in range(K):
            delta2[k] = (y[n, k] - t[n, k])

        # (3) 중간층의 오차 구하기
        for j in range(M):
            delta1[j] = z[n, j] * (1- z[n, j])* np.dot(v[:, j], delta2)

        # (4) v의 기울기 dv 구하기
        for k in range(K):
            dv[k, :] = dv[k, :] + delta2[k] * z[n, :] / N

        # (5) w의 기울기 dw 구하기
        for j in range(M):
            dw[j, :] = dw[j, :] + delta1[j] * np.r_[x[n, :], 1] / N

    # dw와 dv를 합체시킨 dwv로 만들기
    dwv = np.c_[dw.reshape((1, M * (D + 1))), dv.reshape((1, K * (M + 1)))]
    dwv = dwv.reshape(-1)
    return dwv

# %%
# Show dWV
def Show_dWV(wv, M):
    N = wv.shape[0]
    plt.bar(range(1, M * 3 + 1), wv[ : M * 3], align = "center", color = 'black', label = '$dw_{i-1}$')
    plt.bar(range(M * 3 + 1, N + 1), wv[M * 3 : ], align = "center", color = 'cornflowerblue', label = '$dv_{i-1}$')
    plt.xticks(range(1, N + 1))
    plt.xlim(0, N +1)
    plt.legend(loc = "lower left", fontsize = 14)
    plt.xlabel('$i$', fontsize=14)

    
# 동작 확인
M = 2
K = 3
N = 2
nWV = M * 3 + K * (M+1)
np.random.seed(1)
WV = np.random.normal(0, 1, nWV)

dWV_ana = dCE_FNN(WV, M, K, X_train[ : N, : ], T_train[ : N, :])
print("analytical dWV")
print(dWV_ana)

dWV_num = dCE_FNN_num(WV, M, K, X_train[ : N, : ], T_train[ : N, :])
print("numerical dWV")
print(dWV_num)

plt.figure(1, figsize = (8, 3))
plt.subplots_adjust(wspace = 0.5)
plt.subplot(1, 2, 1)
Show_dWV(dWV_ana, M)
plt.title('analitical')
plt.legend(loc = "lower left")
plt.xlabel('$i$', fontsize=14)

plt.subplot(1, 2, 2)
Show_dWV(dWV_num, M)
plt.title('numerical')
plt.legend(loc = "lower left")
plt.xlabel('$i$', fontsize=14)
# Out:
# analytical dWV
# [ 0.08848131  0.19158    -0.051398    0.01281536 -0.14468029 -0.14242768
#  -0.02992012  0.01351315 -0.11115649 -0.10104422 -0.09427964 -0.46855604
#   0.13096434  0.08076649  0.57971253]
# numerical dWV
# [ 0.0884813   0.19157999 -0.05139799  0.01281536 -0.14468029 -0.14242768
#  -0.02992012  0.01351315 -0.11115648 -0.10104422 -0.09427964 -0.46855603
#   0.13096434  0.08076649  0.57971252]
# Text(0.5, 0, '$i$')

# %%
# 리스트 7-1-(12)
# 해석적 미분법에 의한 경사 하강법 (오류 역전파법)

import time

def Fit_FNN(wv_init, M, K, x_train, t_train, x_test, t_test, n, alpha):
    wv = wv_init.copy()
    err_train = np.zeros(n)
    err_test = np.zeros(n)
    wv_hist = np.zeros((n, len(wv_init)))
    epsilon = 0.001

    for i in range(n):
        wv = wv - alpha * dCE_FNN(wv, M, K, x_train, t_train)
        err_train[i] = CE_FNN(wv, M, K, x_train, t_train)
        err_test[i] = CE_FNN(wv, M, K, x_test, t_test)
        wv_hist[i, :] = wv

    return wv, wv_hist, err_train, err_test

# 메인
startTime = time.time()
M = 2
K = 3
np.random.seed(1)
WV_init = np.random.normal(0, 0.01, M * 3 + K * (M+1))
N_step = 1000 # (B) 학습단계
alpha = 0.5 # 학습률
WV, WV_hist, Err_train, Err_test = Fit_FNN(WV_init, M, K, X_train, T_train,
X_test, T_test, N_step, alpha)

calculation_time = time.time() - startTime
print("Calculation time : {0: .3f} sec" .format(calculation_time))
# Out:
# Calculation time :  28.361 sec

# %%
# 리스트 7-1-(13)
plt.figure(1, figsize = (12, 3))
plt.subplots_adjust(wspace = 0.5)

# 학습 오차의 표시
plt.subplot(1, 3, 1)
plt.plot(Err_train, 'black', label = 'training')
plt.plot(Err_test, 'cornflowerblue', label = 'test')
plt.xlabel('steps', fontsize = 11)
plt.ylabel('CE', fontsize = 11)
plt.ylim(0, )
plt.legend()

# 가중치의 시간 변화 표시
plt.subplot(1, 3, 2)
plt.plot(WV_hist[:, : M * 3], 'black')
plt.plot(WV_hist[:, M * 3 :], 'cornflowerblue')
plt.xlabel("steps")

# 경계선 표시
plt.subplot(1, 3, 3)
Show_data(X_test,T_test)
show_FNN(WV, M, K)
plt.xlabel('$x_0$', fontsize = 14)
plt.ylabel('$x_1$', fontsize = 14)
plt.show()

# %%
# GPU 버전 사용하는 경우 GPU 메모리를 필요할 때 마다 할당
# 따로 설정이 없으면 할당 가능한 최대 메모리로 할당

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.compat.v1.Session(config=config)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
np.random.seed(1) # random seed

import tensorflow.keras.optimizers #SGD, Adam 같은 최적화기를 포함함
# 모델의 층(layer)을 쌓아가는 방식의 Sequential Class
from tensorflow.keras.models import Sequential
# 네트워크에 사용할 층을 import, Dense=완전연결층, Activation=활성화 함수
from tensorflow.keras.layers import Dense, Activation

# %%
# 저장한 데이터 불러오기
outfile = np.load('class_data.npz')
X_train = outfile['X_train']
T_train = outfile['T_train']
X_test = outfile['X_test']
T_test = outfile['T_test']
X_range0 = outfile['X_range0']
X_range1 = outfile['X_range1']

# %%
# 리스트 7-2-(3)
# 난수 초기화
np.random.seed(1)

# Sequential 모델 작성
# Sequential 클래스에서 생성된 객체, 케라스는 model에 층을 추가해 네트워크 구조를 정의
model = Sequential()
model.add(Dense(2, input_dim=2, activation='sigmoid',
kernel_initializer = 'uniform'))
# (A) 중간(은닉)층으로 Dense 라는 전결합형의 층을 추가
# 2 = snfustn, input_dim=2 는 입력의 차원
# activation = 'sigmoid' 활성함수 = 시그모이드함수
#kernel_initializer.. 가중치 매개 변수의 초기값을 균일 난수에서 결정

model.add(Dense(3, activation='softmax',
kernel_initializer = 'uniform'))
# (B) 출력층을 Dense 로 추가
# 3 = 출력층 뉴런수

sgd = tensorflow.keras.optimizers.SGD(learning_rate = 1, momentum= 0.0,
decay = 0.0, nesterov = False)

# (C) 경사하강법의 사용
# keras.optimizers.SGD()로 경사하강법 정의
# 1r은 학습률 나머지는 규제

model.compile(optimizer = sgd,
loss = 'categorical_crossentropy', metrics = ['accuracy'])

# (D) model.compile() 을 이용하여 학습 방법 설정
# loss = categorical_crossentropy 는 목적함수를 교차 엔트로피 오차로 지정하고
# metrics = ['acc..' 학습의 평가로 정답률(accurracy) 도 계산하도록 지시

# %%
# 학습
startTime = time.time()
history = model.fit(X_train, T_train, epochs= 1000,
batch_size= 100, verbose = 1,
validation_data = (X_test, T_test))

# (E) 실제 학습은 model.fit으로 실행
# 훈련 데이터를 지정하고
# 배치크기(한 번 기울기를 업데이트하는데 사용하는 데이터 수)
# epochs(전체 데이터를 학습에 사용한 횟수)
# verbose = 0 학습 진행 상황을 표시하지 않음
# validation_data 는 평가용 데이터의 지정
# model.fit 의 return은 학습 과정에 대한 정보를 갖고 있으며 history에 저장

calculation_time =time.time()-startTime
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 451ms/step - loss: 1.0979 - accuracy: 0.4400 - val_loss: 1.0859 - val_accuracy: 0.3800
# Epoch 2/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0778 - accuracy: 0.4400 - val_loss: 1.0837 - val_accuracy: 0.3800
# Epoch 3/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0729 - accuracy: 0.4400 - val_loss: 1.0830 - val_accuracy: 0.3800
# Epoch 4/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0715 - accuracy: 0.4400 - val_loss: 1.0823 - val_accuracy: 0.3800
# Epoch 5/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0708 - accuracy: 0.4400 - val_loss: 1.0816 - val_accuracy: 0.3800
# Epoch 6/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0701 - accuracy: 0.4400 - val_loss: 1.0808 - val_accuracy: 0.3800
# Epoch 7/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0694 - accuracy: 0.4400 - val_loss: 1.0800 - val_accuracy: 0.3800
# Epoch 8/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0686 - accuracy: 0.4400 - val_loss: 1.0792 - val_accuracy: 0.3800
# Epoch 9/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0677 - accuracy: 0.4400 - val_loss: 1.0783 - val_accuracy: 0.3800
# Epoch 10/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0666 - accuracy: 0.4400 - val_loss: 1.0773 - val_accuracy: 0.3800
# Epoch 11/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0654 - accuracy: 0.4400 - val_loss: 1.0761 - val_accuracy: 0.3800
# Epoch 12/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0639 - accuracy: 0.4400 - val_loss: 1.0747 - val_accuracy: 0.3800
# Epoch 13/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0622 - accuracy: 0.4400 - val_loss: 1.0730 - val_accuracy: 0.3800
# Epoch 14/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0602 - accuracy: 0.4400 - val_loss: 1.0710 - val_accuracy: 0.3800
# Epoch 15/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0579 - accuracy: 0.4400 - val_loss: 1.0686 - val_accuracy: 0.3800
# Epoch 16/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0552 - accuracy: 0.4400 - val_loss: 1.0658 - val_accuracy: 0.3800
# Epoch 17/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0520 - accuracy: 0.4400 - val_loss: 1.0626 - val_accuracy: 0.3800
# Epoch 18/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0484 - accuracy: 0.4400 - val_loss: 1.0588 - val_accuracy: 0.3800
# Epoch 19/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0442 - accuracy: 0.4400 - val_loss: 1.0545 - val_accuracy: 0.3800
# Epoch 20/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0394 - accuracy: 0.4400 - val_loss: 1.0496 - val_accuracy: 0.3800
# Epoch 21/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0340 - accuracy: 0.4400 - val_loss: 1.0440 - val_accuracy: 0.3800
# Epoch 22/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0279 - accuracy: 0.4400 - val_loss: 1.0377 - val_accuracy: 0.3800
# Epoch 23/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0211 - accuracy: 0.4400 - val_loss: 1.0308 - val_accuracy: 0.3800
# Epoch 24/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0136 - accuracy: 0.4400 - val_loss: 1.0231 - val_accuracy: 0.3800
# Epoch 25/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0054 - accuracy: 0.4400 - val_loss: 1.0148 - val_accuracy: 0.3800
# Epoch 26/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9964 - accuracy: 0.4400 - val_loss: 1.0059 - val_accuracy: 0.4100
# Epoch 27/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9868 - accuracy: 0.4400 - val_loss: 0.9964 - val_accuracy: 0.4100
# Epoch 28/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9766 - accuracy: 0.4500 - val_loss: 0.9864 - val_accuracy: 0.4500
# Epoch 29/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9659 - accuracy: 0.4700 - val_loss: 0.9759 - val_accuracy: 0.4600
# Epoch 30/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9546 - accuracy: 0.4900 - val_loss: 0.9651 - val_accuracy: 0.4900
# Epoch 31/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9430 - accuracy: 0.5200 - val_loss: 0.9541 - val_accuracy: 0.5200
# Epoch 32/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9312 - accuracy: 0.5700 - val_loss: 0.9429 - val_accuracy: 0.5300
# Epoch 33/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9191 - accuracy: 0.5800 - val_loss: 0.9316 - val_accuracy: 0.6000
# Epoch 34/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9069 - accuracy: 0.5800 - val_loss: 0.9203 - val_accuracy: 0.6300
# Epoch 35/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8948 - accuracy: 0.5900 - val_loss: 0.9091 - val_accuracy: 0.6500
# Epoch 36/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.8826 - accuracy: 0.5900 - val_loss: 0.8981 - val_accuracy: 0.6600
# Epoch 37/1000
# 1/1 [==============================] - 0s 34ms/step - loss:
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3224 - accuracy: 0.9300 - val_loss: 0.4030 - val_accuracy: 0.8600
# Epoch 134/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3202 - accuracy: 0.9300 - val_loss: 0.4007 - val_accuracy: 0.8600
# Epoch 135/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3180 - accuracy: 0.9300 - val_loss: 0.3984 - val_accuracy: 0.8600
# Epoch 136/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3159 - accuracy: 0.9300 - val_loss: 0.3962 - val_accuracy: 0.8600
# Epoch 137/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3138 - accuracy: 0.9300 - val_loss: 0.3941 - val_accuracy: 0.8600
# Epoch 138/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.3118 - accuracy: 0.9300 - val_loss: 0.3920 - val_accuracy: 0.8600
# Epoch 139/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3099 - accuracy: 0.9300 - val_loss: 0.3900 - val_accuracy: 0.8600
# Epoch 140/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3080 - accuracy: 0.9300 - val_loss: 0.3880 - val_accuracy: 0.8600
# Epoch 141/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3061 - accuracy: 0.9300 - val_loss: 0.3860 - val_accuracy: 0.8600
# Epoch 142/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3044 - accuracy: 0.9200 - val_loss: 0.3842 - val_accuracy: 0.8600
# Epoch 143/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3026 - accuracy: 0.9200 - val_loss: 0.3823 - val_accuracy: 0.8600
# Epoch 144/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3010 - accuracy: 0.9200 - val_loss: 0.3805 - val_accuracy: 0.8600
# Epoch 145/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2993 - accuracy: 0.9200 - val_loss: 0.3788 - val_accuracy: 0.8600
# Epoch 146/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2977 - accuracy: 0.9200 - val_loss: 0.3771 - val_accuracy: 0.8600
# Epoch 147/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2962 - accuracy: 0.9200 - val_loss: 0.3754 - val_accuracy: 0.8600
# Epoch 148/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2947 - accuracy: 0.9200 - val_loss: 0.3738 - val_accuracy: 0.8600
# Epoch 149/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2932 - accuracy: 0.9200 - val_loss: 0.3722 - val_accuracy: 0.8600
# Epoch 150/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2918 - accuracy: 0.9200 - val_loss: 0.3707 - val_accuracy: 0.8600
# Epoch 151/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2904 - accuracy: 0.9200 - val_loss: 0.3692 - val_accuracy: 0.8600
# Epoch 152/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2890 - accuracy: 0.9200 - val_loss: 0.3677 - val_accuracy: 0.8600
# Epoch 153/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2877 - accuracy: 0.9200 - val_loss: 0.3663 - val_accuracy: 0.8600
# Epoch 154/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2864 - accuracy: 0.9200 - val_loss: 0.3649 - val_accuracy: 0.8600
# Epoch 155/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2852 - accuracy: 0.9200 - val_loss: 0.3635 - val_accuracy: 0.8600
# Epoch 156/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2839 - accuracy: 0.9200 - val_loss: 0.3621 - val_accuracy: 0.8600
# Epoch 157/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2828 - accuracy: 0.9200 - val_loss: 0.3608 - val_accuracy: 0.8600
# Epoch 158/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2816 - accuracy: 0.9200 - val_loss: 0.3596 - val_accuracy: 0.8600
# Epoch 159/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2805 - accuracy: 0.9200 - val_loss: 0.3583 - val_accuracy: 0.8600
# Epoch 160/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2794 - accuracy: 0.9200 - val_loss: 0.3571 - val_accuracy: 0.8600
# Epoch 161/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2783 - accuracy: 0.9200 - val_loss: 0.3559 - val_accuracy: 0.8600
# Epoch 162/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2772 - accuracy: 0.9200 - val_loss: 0.3547 - val_accuracy: 0.8600
# Epoch 163/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.
1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2544 - accuracy: 0.9200 - val_loss: 0.3288 - val_accuracy: 0.8500
# Epoch 193/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2538 - accuracy: 0.9200 - val_loss: 0.3282 - val_accuracy: 0.8500
# Epoch 194/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2533 - accuracy: 0.9200 - val_loss: 0.3276 - val_accuracy: 0.8500
# Epoch 195/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2528 - accuracy: 0.9200 - val_loss: 0.3270 - val_accuracy: 0.8600
# Epoch 196/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2523 - accuracy: 0.9200 - val_loss: 0.3264 - val_accuracy: 0.8600
# Epoch 197/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2518 - accuracy: 0.9200 - val_loss: 0.3258 - val_accuracy: 0.8600
# Epoch 198/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2513 - accuracy: 0.9200 - val_loss: 0.3252 - val_accuracy: 0.8600
# Epoch 199/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2508 - accuracy: 0.9200 - val_loss: 0.3246 - val_accuracy: 0.8600
# Epoch 200/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2503 - accuracy: 0.9200 - val_loss: 0.3241 - val_accuracy: 0.8600
# Epoch 201/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2498 - accuracy: 0.9200 - val_loss: 0.3235 - val_accuracy: 0.8600
# Epoch 202/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2494 - accuracy: 0.9200 - val_loss: 0.3230 - val_accuracy: 0.8600
# Epoch 203/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2489 - accuracy: 0.9200 - val_loss: 0.3225 - val_accuracy: 0.8600
# Epoch 204/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2485 - accuracy: 0.9200 - val_loss: 0.3219 - val_accuracy: 0.8600
# Epoch 205/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2480 - accuracy: 0.9200 - val_loss: 0.3214 - val_accuracy: 0.8700
# Epoch 206/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2476 - accuracy: 0.9200 - val_loss: 0.3209 - val_accuracy: 0.8700
# Epoch 207/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2472 - accuracy: 0.9200 - val_loss: 0.3204 - val_accuracy: 0.8700
# Epoch 208/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2467 - accuracy: 0.9200 - val_loss: 0.3199 - val_accuracy: 0.8700
# Epoch 209/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2463 - accuracy: 0.9200 - val_loss: 0.3194 - val_accuracy: 0.8700
# Epoch 210/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2459 - accuracy: 0.9200 - val_loss: 0.3190 - val_accuracy: 0.8700
# Epoch 211/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2455 - accuracy: 0.9200 - val_loss: 0.3185 - val_accuracy: 0.8700
# Epoch 212/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2451 - accuracy: 0.9200 - val_loss: 0.3180 - val_accuracy: 0.8700
# Epoch 213/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2448 - accuracy: 0.9200 - val_loss: 0.3176 - val_accuracy: 0.8700
# Epoch 214/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2444 - accuracy: 0.9200 - val_loss: 0.3172 - val_accuracy: 0.8700
# Epoch 215/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2440 - accuracy: 0.9200 - val_loss: 0.3167 - val_accuracy: 0.8700
# Epoch 216/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2436 - accuracy: 0.9200 - val_loss: 0.3163 - val_accuracy: 0.8700
# Epoch 217/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2433 - accuracy: 0.9200 - val_loss: 0.3159 - val_accuracy: 0.8700
# Epoch 218/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2429 - accuracy: 0.9200 - val_loss: 0.3154 - val_accuracy: 0.8700
# Epoch 219/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2426 - accuracy: 0.9200 - val_loss: 0.3150 - val_accuracy: 0.8700
# Epoch 220/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2422 - accuracy: 0.9200 - val_loss: 0.3146 - val_accuracy: 0.8700
# Epoch 221/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2419 - accuracy: 0.9200 - val_loss: 0.3142 - val_accuracy: 0.8700
# Epoch 222/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2416 - accuracy: 0.9200 - val_loss: 0.3138 - val_accuracy: 0.8700
# Epoch 223/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2412 - accuracy: 0.9200 - val_loss: 0.3134 - val_accuracy: 0.8700
# Epoch 224/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2409 - accuracy: 0.9200 - val_loss: 0.3131 - val_accuracy: 0.8700
# Epoch 225/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2406 - accuracy: 0.9200 - val_loss: 0.3127 - val_accuracy: 0.8700
# Epoch 226/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2403 - accuracy: 0.9200 - val_loss: 0.3123 - val_accuracy: 0.8700
# Epoch 227/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2400 - accuracy: 0.9200 - val_loss: 0.3119 - val_accuracy: 0.8700
# Epoch 228/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2397 - accuracy: 0.9200 - val_loss: 0.3116 - val_accuracy: 0.8700
# Epoch 229/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2394 - accuracy: 0.9200 - val_loss: 0.3112 - val_accuracy: 0.8700
# Epoch 230/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2391 - accuracy: 0.9200 - val_loss: 0.3109 - val_accuracy: 0.8700
# Epoch 231/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2388 - accuracy: 0.9200 - val_loss: 0.3105 - val_accuracy: 0.8700
# Epoch 232/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2385 - accuracy: 0.9200 - val_loss: 0.3102 - val_accuracy: 0.8700
# Epoch 233/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2382 - accuracy: 0.9200 - val_loss: 0.3098 - val_accuracy: 0.8700
# Epoch 234/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2379 - accuracy: 0.9200 - val_loss: 0.3095 - val_accuracy: 0.8700
# Epoch 235/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2377 - accuracy: 0.9200 - val_loss: 0.3092 - val_accuracy: 0.8700
# Epoch 236/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2374 - accuracy: 0.9200 - val_loss: 0.3089 - val_accuracy: 0.8700
# Epoch 237/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2371 - accuracy: 0.9200 - val_loss: 0.3085 - val_accuracy: 0.8700
# Epoch 238/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2369 - accuracy: 0.9200 - val_loss: 0.3082 - val_accuracy: 0.8700
# Epoch 239/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2366 - accuracy: 0.9200 - val_loss: 0.3079 - val_accuracy: 0.8700
# Epoch 240/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2363 - accuracy: 0.9200 - val_loss: 0.3076 - val_accuracy: 0.8700
# Epoch 241/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2361 - accuracy: 0.9200 - val_loss: 0.3073 - val_accuracy: 0.8700
# Epoch 242/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2358 - accuracy: 0.9200 - val_loss: 0.3070 - val_accuracy: 0.8700
# Epoch 243/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2356 - accuracy: 0.9200 - val_loss: 0.3067 - val_accuracy: 0.8700
# Epoch 244/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2354 - accuracy: 0.9200 - val_loss: 0.3064 - val_accuracy: 0.8700
# Epoch 245/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2351 - accuracy: 0.9200 - val_loss: 0.3061 - val_accuracy: 0.8700
# Epoch 246/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2349 - accuracy: 0.9200 - val_loss: 0.3058 - val_accuracy: 0.8700
# Epoch 247/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2347 - accuracy: 0.9200 - val_loss: 0.3056 - val_accuracy: 0.8700
# Epoch 248/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2344 - accuracy: 0.9200 - val_loss: 0.3053 - val_accuracy: 0.8700
# Epoch 249/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2342 - accuracy: 0.9100 - val_loss: 0.3050 - val_accuracy: 0.8700
# Epoch 250/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2340 - accuracy: 0.9100 - val_loss: 0.3047 - val_accuracy: 0.8700
# Epoch 251/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2338 - accuracy: 0.9100 - val_loss: 0.3045 - val_accuracy: 0.8700
# Epoch 252/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2335 - accuracy: 0.9100 - val_loss: 0.3042 - val_accuracy: 0.8700
# Epoch 253/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2333 - accuracy: 0.9100 - val_loss: 0.3040 - val_accuracy: 0.8700
# Epoch 254/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2331 - accuracy: 0.9100 - val_loss: 0.3037 - val_accuracy: 0.8700
# Epoch 255/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2329 - accuracy: 0.9100 - val_loss: 0.3034 - val_accuracy: 0.8700
# Epoch 256/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2327 - accuracy: 0.9100 - val_loss: 0.3032 - val_accuracy: 0.8700
# Epoch 257/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2325 - accuracy: 0.9100 - val_loss: 0.3029 - val_accuracy: 0.8700
# Epoch 258/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2323 - accuracy: 0.9100 - val_loss: 0.3027 - val_accuracy: 0.8700
# Epoch 259/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2321 - accuracy: 0.9100 - val_loss: 0.3025 - val_accuracy: 0.8700
# Epoch 260/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2319 - accuracy: 0.9100 - val_loss: 0.3022 - val_accuracy: 0.8700
# Epoch 261/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2317 - accuracy: 0.9100 - val_loss: 0.3020 - val_accuracy: 0.8700
# Epoch 262/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2315 - accuracy: 0.9100 - val_loss: 0.3017 - val_accuracy: 0.8700
# Epoch 263/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2313 - accuracy: 0.9100 - val_loss: 0.3015 - val_accuracy: 0.8700
# Epoch 264/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2311 - accuracy: 0.9100 - val_loss: 0.3013 - val_accuracy: 0.8800
# Epoch 265/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2310 - accuracy: 0.9100 - val_loss: 0.3011 - val_accuracy: 0.8800
# Epoch 266/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2308 - accuracy: 0.9100 - val_loss: 0.3008 - val_accuracy: 0.8800
# Epoch 267/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2306 - accuracy: 0.9100 - val_loss: 0.3006 - val_accuracy: 0.8800
# Epoch 268/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2304 - accuracy: 0.9100 - val_loss: 0.3004 - val_accuracy: 0.8800
# Epoch 269/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2302 - accuracy: 0.9100 - val_loss: 0.3002 - val_accuracy: 0.8800
# Epoch 270/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2301 - accuracy: 0.9100 - val_loss: 0.3000 - val_accuracy: 0.8800
# Epoch 271/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2299 - accuracy: 0.9100 - val_loss: 0.2998 - val_accuracy: 0.8800
# Epoch 272/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2297 - accuracy: 0.9100 - val_loss: 0.2996 - val_accuracy: 0.8800
# Epoch 273/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2296 - accuracy: 0.9100 - val_loss: 0.2993 - val_accuracy: 0.8800
# Epoch 274/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2294 - accuracy: 0.9100 - val_loss: 0.2991 - val_accuracy: 0.8800
# Epoch 275/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2292 - accuracy: 0.9100 - val_loss: 0.2989 - val_accuracy: 0.8800
# Epoch 276/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2291 - accuracy: 0.9100 - val_loss: 0.2987 - val_accuracy: 0.8800
# Epoch 277/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2289 - accuracy: 0.9100 - val_loss: 0.2985 - val_accuracy: 0.8800
# Epoch 278/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2288 - accuracy: 0.9100 - val_loss: 0.2983 - val_accuracy: 0.8800
# Epoch 279/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2286 - accuracy: 0.9100 - val_loss: 0.2982 - val_accuracy: 0.8800
# Epoch 280/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2285 - accuracy: 0.9100 - val_loss: 0.2980 - val_accuracy: 0.8800
# Epoch 281/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2283 - accuracy: 0.9100 - val_loss: 0.2978 - val_accuracy: 0.8800
# Epoch 282/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2282 - accuracy: 0.9100 - val_loss: 0.2976 - val_accuracy: 0.8800
# Epoch 283/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2280 - accuracy: 0.9100 - val_loss: 0.2974 - val_accuracy: 0.8800
# Epoch 284/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2279 - accuracy: 0.9100 - val_loss: 0.2972 - val_accuracy: 0.8800
# Epoch 285/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2277 - accuracy: 0.9100 - val_loss: 0.2970 - val_accuracy: 0.8800
# Epoch 286/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2276 - accuracy: 0.9100 - val_loss: 0.2969 - val_accuracy: 0.8800
# Epoch 287/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2274 - accuracy: 0.9100 - val_loss: 0.2967 - val_accuracy: 0.8800
# Epoch 288/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2273 - accuracy: 0.9100 - val_loss: 0.2965 - val_accuracy: 0.8800
# Epoch 289/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2272 - accuracy: 0.9100 - val_loss: 0.2963 - val_accuracy: 0.8800
# Epoch 290/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2270 - accuracy: 0.9100 - val_loss: 0.2962 - val_accuracy: 0.8800
# Epoch 291/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2269 - accuracy: 0.9100 - val_loss: 0.2960 - val_accuracy: 0.8800
# Epoch 292/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2267 - accuracy: 0.9100 - val_loss: 0.2958 - val_accuracy: 0.8800
# Epoch 293/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2266 - accuracy: 0.9100 - val_loss: 0.2957 - val_accuracy: 0.8800
# Epoch 294/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2265 - accuracy: 0.9100 - val_loss: 0.2955 - val_accuracy: 0.8800
# Epoch 295/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2264 - accuracy: 0.9100 - val_loss: 0.2953 - val_accuracy: 0.8800
# Epoch 296/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2262 - accuracy: 0.9100 - val_loss: 0.2952 - val_accuracy: 0.8800
# Epoch 297/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2261 - accuracy: 0.9100 - val_loss: 0.2950 - val_accuracy: 0.8800
# Epoch 298/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2260 - accuracy: 0.9100 - val_loss: 0.2948 - val_accuracy: 0.8800
# Epoch 299/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2258 - accuracy: 0.9100 - val_loss: 0.2947 - val_accuracy: 0.8800
# Epoch 300/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2257 - accuracy: 0.9100 - val_loss: 0.2945 - val_accuracy: 0.8800
# Epoch 301/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2256 - accuracy: 0.9100 - val_loss: 0.2944 - val_accuracy: 0.8800
# Epoch 302/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2255 - accuracy: 0.9100 - val_loss: 0.2942 - val_accuracy: 0.8800
# Epoch 303/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2254 - accuracy: 0.9100 - val_loss: 0.2941 - val_accuracy: 0.8800
# Epoch 304/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2252 - accuracy: 0.9100 - val_loss: 0.2939 - val_accuracy: 0.8800
# Epoch 305/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2251 - accuracy: 0.9100 - val_loss: 0.2938 - val_accuracy: 0.8800
# Epoch 306/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2250 - accuracy: 0.9100 - val_loss: 0.2936 - val_accuracy: 0.8800
# Epoch 307/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2249 - accuracy: 0.9100 - val_loss: 0.2935 - val_accuracy: 0.8800
# Epoch 308/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2248 - accuracy: 0.9100 - val_loss: 0.2933 - val_accuracy: 0.8900
# Epoch 309/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2247 - accuracy: 0.9100 - val_loss: 0.2932 - val_accuracy: 0.8900
# Epoch 310/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2246 - accuracy: 0.9100 - val_loss: 0.2930 - val_accuracy: 0.8900
# Epoch 311/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2245 - accuracy: 0.9100 - val_loss: 0.2929 - val_accuracy: 0.8900
# Epoch 312/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2243 - accuracy: 0.9100 - val_loss: 0.2928 - val_accuracy: 0.8900
# Epoch 313/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2242 - accuracy: 0.9100 - val_loss: 0.2926 - val_accuracy: 0.8900
# Epoch 314/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2241 - accuracy: 0.9100 - val_loss: 0.2925 - val_accuracy: 0.8900
# Epoch 315/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2240 - accuracy: 0.9100 - val_loss: 0.2924 - val_accuracy: 0.8900
# Epoch 316/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2239 - accuracy: 0.9100 - val_loss: 0.2922 - val_accuracy: 0.8900
# Epoch 317/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2238 - accuracy: 0.9100 - val_loss: 0.2921 - val_accuracy: 0.8900
# Epoch 318/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2237 - accuracy: 0.9100 - val_loss: 0.2920 - val_accuracy: 0.8900
# Epoch 319/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2236 - accuracy: 0.9100 - val_loss: 0.2918 - val_accuracy: 0.8900
# Epoch 320/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2235 - accuracy: 0.9100 - val_loss: 0.2917 - val_accuracy: 0.8900
# Epoch 321/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2234 - accuracy: 0.9100 - val_loss: 0.2916 - val_accuracy: 0.8900
# Epoch 322/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2233 - accuracy: 0.9100 - val_loss: 0.2914 - val_accuracy: 0.8900
# Epoch 323/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2232 - accuracy: 0.9100 - val_loss: 0.2913 - val_accuracy: 0.8900
# Epoch 324/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2231 - accuracy: 0.9100 - val_loss: 0.2912 - val_accuracy: 0.8900
# Epoch 325/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2230 - accuracy: 0.9100 - val_loss: 0.2911 - val_accuracy: 0.8900
# Epoch 326/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2229 - accuracy: 0.9100 - val_loss: 0.2909 - val_accuracy: 0.8900
# Epoch 327/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2228 - accuracy: 0.9100 - val_loss: 0.2908 - val_accuracy: 0.8900
# Epoch 328/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2227 - accuracy: 0.9100 - val_loss: 0.2907 - val_accuracy: 0.8900
# Epoch 329/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2227 - accuracy: 0.9100 - val_loss: 0.2906 - val_accuracy: 0.8900
# Epoch 330/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2226 - accuracy: 0.9100 - val_loss: 0.2905 - val_accuracy: 0.8900
# Epoch 331/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2225 - accuracy: 0.9100 - val_loss: 0.2903 - val_accuracy: 0.8900
# Epoch 332/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2224 - accuracy: 0.9100 - val_loss: 0.2902 - val_accuracy: 0.8900
# Epoch 333/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2223 - accuracy: 0.9100 - val_loss: 0.2901 - val_accuracy: 0.8900
# Epoch 334/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2222 - accuracy: 0.9100 - val_loss: 0.2900 - val_accuracy: 0.8900
# Epoch 335/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2221 - accuracy: 0.9100 - val_loss: 0.2899 - val_accuracy: 0.8900
# Epoch 336/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2220 - accuracy: 0.9100 - val_loss: 0.2898 - val_accuracy: 0.8900
# Epoch 337/1000
# ...
# Epoch 890/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 891/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 892/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 893/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 894/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 895/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 896/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 897/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 898/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2086 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 899/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 900/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 901/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9000
# Epoch 902/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 903/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 904/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 905/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 906/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 907/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2685 - val_accuracy: 0.9000
# Epoch 908/1000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 909/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 910/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2085 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 911/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 912/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 913/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 914/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 915/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 916/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 917/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 918/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 919/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 920/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 921/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 922/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2084 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 923/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 924/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 925/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 926/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 927/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 928/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 929/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 930/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 931/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9000
# Epoch 932/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 933/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 934/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 935/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 936/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 937/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 938/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 939/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 940/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 941/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 942/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 943/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 944/1000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 945/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 946/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 947/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2082 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 948/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 949/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 950/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2678 - val_accuracy: 0.9000
# Epoch 951/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 952/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 953/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 954/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 955/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2081 - accuracy: 0.9100 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 956/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2081 - accuracy: 0.9200 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 957/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.2081 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 958/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2081 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 959/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2081 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 960/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 961/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 962/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 963/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 964/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 965/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 966/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 967/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 968/1000
# 1/1 [==============================] - 0s 143ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 969/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 970/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 971/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 972/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.2080 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 973/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 974/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 975/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 976/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 977/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 978/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 979/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 980/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 981/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 982/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 983/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 984/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 985/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2079 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 986/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 987/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 988/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 989/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 990/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 991/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 992/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 993/1000
# 1/1 [==============================] - 0s 154ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 994/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 995/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 996/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 997/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2670 - val_accuracy: 0.9000
# Epoch 998/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2078 - accuracy: 0.9200 - val_loss: 0.2670 - val_accuracy: 0.9000
# Epoch 999/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2077 - accuracy: 0.9200 - val_loss: 0.2670 - val_accuracy: 0.9000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2077 - accuracy: 0.9200 - val_loss: 0.2670 - val_accuracy: 0.9000

# %%
history = history.history
history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
score = model.evaluate(X_test, T_test, verbose=0)

print('cross entropy {0: 3.2f}, accuracy {1: 3.2f}' .format(score[0], score[1]))
print("Calculation time : {0: .3f} sec" .format(calculation_time))
# Out:
# cross entropy  0.27, accuracy  0.90
# Calculation time :  49.708 sec

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 데이터를 그리기
def Show_data(x, t):
    wk, n = t.shape
    c = [[0, 0, 0], [0.5, 0.5, 0.5], [1, 1, 1]] # 컬러 값 설정
    #c = [[1, 0, 0], [0, 1, 0], [0, 0, 1]] # 컬러 값 설정 [r, g, b]
    
    for i in range(n):
         plt.plot(x[t[:, i] == 1, 0], x[t[:, i] == 1, 1], linestyle = 'none', markeredgecolor = 'black', marker = 'o', color = c[i], alpha = 0.8)
        # K 값을 0, 1, 2로 바꾸어 주면서 부류벡터 t 에 접근 부류번호가 일치하는 인덱스드을 모두 찾아준다
        # 따라서, 부류가 0번인 샘플들의 (x1, x2) 위치에 포인트를 먼저 다 찍고, 그 다음 부류로 순차적으로 찍게 된다
    plt.grid(True)
    
# 리스트 7-2-(4)
plt.figure(1, figsize = (16, 4))
plt.subplots_adjust(wspace = 0.5)

# 학습 곡선 표시
plt.subplot(1, 3, 1)
plt.plot(history['loss'], 'black', label = 'training')
# (A) 학습 과정의 훈련 데이터의 교차 엔트로피 오차의 시계열 정보
plt.plot(history['val_loss'], 'cornflowerblue', label ='test')
# (B) 학습 과정의 평가용 데이터의의 교차 엔트로피 오차
plt.legend()
plt.xlabel('epochs')
plt.ylabel('CEE')
plt.title('History of Loss function', fontsize = 14)


# 정확도 표시
plt.subplot(1, 3, 2)
plt.plot(history['accuracy'], 'black', label = 'training') 
# (C) 훈련 데이터의 정답률 변화
plt.plot(history['val_accuracy'], 'cornflowerblue', label = 'test')
# (D) 평가용 데이터의 정답률 변화
plt.legend()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('History of Accuracy', fontsize = 14)


# 경계선 표시
plt.subplot(1, 3, 3)
Show_data(X_test, T_test)
xn = 60 # 등고선 표시 해상도
x0 = np.linspace(X_range0[0], X_range0[1], xn)
x1 = np.linspace(X_range1[0], X_range1[1], xn)
xx0, xx1 = np.meshgrid(x0, x1)
x = np.c_[np.reshape(xx0, xn * xn, 'F'), np.reshape(xx1, xn * xn, 'F')] # np.c_ column 추가
#y, a, z, b = FNN(wv, M, K, x)
y = model.predict(x) # (E) 학습이 완료된 모델에 입력 x에 대한  출력
K = 3

for ic in range(K):
    f = y[: , ic]
    f = f.reshape(xn, xn)
    f = f.T
    cont = plt.contour(xx0, xx1, f, levels = [0.5, 0.8, 0.9], colors = ['gray', 'cornflowerblue', 'black'])
    cont.clabel(fmt = '%1.1f', fontsize = 9)

plt.xlim(X_range0)
plt.ylim(X_range1)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.title('Decision Line', fontsize = 14)

plt.show()
# Out:
# 113/113 [==============================] - 0s 3ms/step
